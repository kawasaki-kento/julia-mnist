# %% [markdown]
# # GPUの確認

# %%
# !nvidia-smi
# Out:
# Wed May 26 09:32:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # パッケージを呼び出し

# %%
import tensorflow as tf

# %% [markdown]
# # データ読み込み

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0 # 正規化
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # モデル定義

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %% [markdown]
# # 学習

# %%
# %%time
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.4885 - accuracy: 0.8558
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2918 - accuracy: 0.9137
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2485 - accuracy: 0.9264
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2252 - accuracy: 0.9311
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2057 - accuracy: 0.9374
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1919 - accuracy: 0.9409
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1827 - accuracy: 0.9432
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1780 - accuracy: 0.9440
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1689 - accuracy: 0.9470
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1639 - accuracy: 0.9483
# CPU times: user 33.3 s, sys: 3.32 s, total: 36.7 s
# Wall time: 41.5 s

# %% [markdown]
# # テスト

# %%
model.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 0s - loss: 0.1184 - accuracy: 0.9648
# [0.1184416115283966, 0.9648000001907349]
